# %% [markdown]
# <a href="https://colab.research.google.com/github/marquee-dev/E-Ration-App/blob/main/TTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/tttzof351/SimpleTransfromerTTS.git
# Out:
# Cloning into 'SimpleTransfromerTTS'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 53 (delta 24), reused 41 (delta 12), pack-reused 0 (from 0)
# Receiving objects: 100% (53/53), 178.70 KiB | 29.78 MiB/s, done.
# Resolving deltas: 100% (24/24), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r '/content/SimpleTransfromerTTS' '/content/drive/MyDrive/Colab Notebooks'
# Out:
# cp: cannot stat '/content/SimpleTransfromerTTS': No such file or directory

# %%
# !cp -r '/content/drive/MyDrive/Colab Notebooks' '/content/SimpleTransfromerTTS'

# %%
# %cd SimpleTransfromerTTS
# Out:
# /content/SimpleTransfromerTTS

# %%
# !pip install torch matplotlib librosa tqdm

# %%
# Out:
# ...
# 100%|██████████| 2.99G/2.99G [00:34<00:00, 93.0MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/mathurinache/the-lj-speech-dataset/versions/1
# Dataset moved to: /content/data
# ...
# 100%|██████████| 599k/599k [00:00<00:00, 105MB/s]
# Extracting files...
# Path to metadata files: /root/.cache/kagglehub/datasets/tttzof351/ljspeech-meta/versions/1
# Metadata moved to: /content/data

# %%
# !python train.py
# Out:
# 2025-01-05 09:23:54.014152: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-05 09:23:54.035283: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-05 09:23:54.041204: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-05 09:23:54.055247: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !pip install pydub

# %%
# %cd /content/SimpleTransfromerTTS/SimpleTransfromerTTS
# Out:
# /content/SimpleTransfromerTTS/SimpleTransfromerTTS

# %%
import os
os.getcwd()
# Out:
# '/content/SimpleTransfromerTTS/SimpleTransfromerTTS'

# %%
# !python inference.py
# Out:
# /content/SimpleTransfromerTTS/SimpleTransfromerTTS/inference.py:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(train_saved_path)
# ...

# %%
from IPython.display import Audio

# Assuming the file is saved as "hello_world.mp3"
Audio("hello_world.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import gdown

# Replace with your file ID
file_id = "12CZIP-tLFcteT2RRfG6__w3_T47m-QJK"
destination = "train_SimpleTransfromerTTS.pt"  # Replace with your desired file name

gdown.download(f"https://drive.google.com/uc?id={file_id}", destination, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=12CZIP-tLFcteT2RRfG6__w3_T47m-QJK
# From (redirected): https://drive.google.com/uc?id=12CZIP-tLFcteT2RRfG6__w3_T47m-QJK&confirm=t&uuid=a93a4fce-3f18-498c-90a0-fb4fd5cd2c76
# To: /content/SimpleTransfromerTTS/SimpleTransfromerTTS/train_SimpleTransfromerTTS.pt
# 100%|██████████| 373M/373M [00:10<00:00, 34.8MB/s]
# 'train_SimpleTransfromerTTS.pt'
